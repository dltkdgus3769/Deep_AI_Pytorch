# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np

##############################################################
import json
import re

# ✅ JSON 파일 읽기
file_path = "취업_naver_news.json"

with open(file_path, "r", encoding="utf-8") as file:
    news_data = json.load(file)  # JSON 데이터 로드
##############################################################

# ✅ 샘플 데이터셋 (문장 예제)
corpus = [
   "나는 너를 사랑해",
    "나는 코딩을 좋아해",
    "너는 나를 좋아해",
    "너는 파이썬을 공부해",
    "우리는 인공지능을 연구해",
    "딥러닝은 재미있어",
    "파이썬은 강력해",
    "나는 자연어처리를 공부해",
]
##############################################################
# ✅ JSON 데이터에서 'title' 값만 추출하고 한글만 남기기
def extract_korean(text):
    """문장에서 한글만 남기는 함수"""
    return re.sub(r"[^ㄱ-ㅎ가-힣 ]+", " ", text)

news_titles = [extract_korean(item["title"]) for item in news_data if "title" in item]

# ✅ corpus에 한글만 남긴 뉴스 제목 추가
corpus.extend(news_titles)

# ✅ 결과 출력
print("📌 최종 corpus 리스트:")
print(corpus)
##############################################################

# ✅ 단어 사전 만들기 (Tokenization)
word_list = list(set(" ".join(corpus).split()))
word_dict = {w: i for i, w in enumerate(word_list)}
idx_dict = {i: w for w, i in word_dict.items()}
# Out:
# 📌 최종 corpus 리스트:
# ['나는 너를 사랑해', '나는 코딩을 좋아해', '너는 나를 좋아해', '너는 파이썬을 공부해', '우리는 인공지능을 연구해', '딥러닝은 재미있어', '파이썬은 강력해', '나는 자연어처리를 공부해', '경북교육청   학년도 고입전형 분석 결과 발표', '건국대  고용노동부   졸업생 특화 프로그램 사업  선정', '경북지역 고등학교 진학한 타시도 학생 지속적 증가', '고양시  교육발전특구 중부대학교       개소', ' 뷰티대학교육협회  경인여자대학교 뷰티디자인학과와   및   체결', '고양특례시  산업기반 인재양성 본격화', '부안군 근농인재육성재단   년  학기 장학생 신청 접수', ' 손해보험  자립준비청년 기술 교육 지원으로  돌봄  공백 해소', '한수원  상반기 신입사원  명 채용 일 접수 마감', '신용보증기금  우수 인재  신입직원  명  공개 채용', '고양시  중부대학교에  고양      개소', ' 손해보험  자립준비청년 기술 교육  런런챌린지   기 시작', '은행권   일부터 서민금융진흥원 출연금 인상', '교육부  제 회 교육 공공데이터 분석 활용 대회 개최', '원광대  전라북도   지역특성화산업 전문인력양성사업 선정', ' 선우은숙 친언니 강제추행  구속된 유영재  항소심 첫 공판  월  일 진 ', ' 일과 육아  여전히 양자택일 우울한 여성들', '경북 고교  타 시도 학생 유입  천 명  유입  유출 대비  배 많아', '송파새일센터   년   백엔드 개발자 과정 교육생 모집', '괴산군노인복지관  노인 경제자립 도울  취업 알선형 사업 추진', '신용보증기금  상반기 신입직원  명 채용', '  아르바이트 청년  건보료 경감  논의  표심  겨냥', '조선이공대학교   지역맞춤형 일자리 사업  수행기관 선정', '한수원  올해 상반기 신입사원  명 채용 일 접수 마감', '함안군  지역특화형 비자사업 시행 비자요건 완화 우수인재  명 유치', '경북교육청   학년도 고입전형 분석 결과 발표', '완도군  경력 단절 여성 재 취업  위해  만 원 지원', '법무보호복지공단 경북지부 안동위원회 정기총회 개최', '여  비수도권   규제 완화 한시적 부동산 세제 개편 검토해야 ', '대구대 식품가공외식학과  한상배 한국식품안전관리인증원장 특강', '양천구  교육부터  취업 까지     세 이상 일자리 지원', '부천시   일 문화산업 유관기관 통합사업설명회 열어', '  한발 더  롯데장학재단 문화재단 이랜드재단  미래 세대 지원 ', '신보   년도 상반기 신입직원  명 채용', '신보   년도 상반기 신입직원  명 채용', '경북보건대 스마트물류과  스마트그린물류 민간기업 비즈니스 실증 국책 ', '장윤정 의원  안산시직업교육혁신지구선정  환영 ', '군산시 이민자 사회통합프로그램 개강', '고교유학생 증가한 경북 유입  명   유출  명 ', '조선이공대 프랜차이즈창업경영과   지역맞춤형 일자리 사업  수행기 ', '중진공   찾아가는 채용설명회  개최', '경북교육청  전국 최초  광역 기초 동시 운영  직업교육 혁신 지구 선정', '대전시  올해 양질 일자리  개 창출 국비  억 확보 ', '일자리 활성화 정보교류 인천채용박람회 올해  회 개최', '경북교육청   전국 최초  직업교육 혁신 지구 광역지구 기초지구 동시 ', ' 제도 개선 취업  확대  박한동 대학축구연맹 회장 취임  유승민 ', '신보  상반기 신입직원 채용', '제천시  구직자 맞춤형  취업 역량 강화교육 운영 개시', '논산시 논산형 청년정책 추진', '    엔터비즈니스 마스터 클래스   기 모집 엔터 산업 인재 양성', '제천시  세명대 대원대에 출장전입신고 접수처 운영', '체코 원전 수주  눈앞  한수원  신입  여명 채용절차 개시', '완도군  재 취업  희망 여성  경력이음바우처  모집', '두나무 송치형 회장  청년들의 미래 밝히는  넥스트 시리즈  시행', '인재 확보와 조직 활력까지 서울 청년 예비인턴  기업 참여 모집 시작', '원티드랩  전 국민 이직 챌린지  대이직시대  진행', '포항시  교육부  직업교육 혁신지구  선정  맞춤형 인재 양성 본격화', '한수원   년 상반기 신입사원 채용', '한수원   년 상반기 신입사원 채용 대졸수준  명 선발 예정', '고양시 교육발전특구 중부대학교  고양      개소', '대전자동차정비학원 현대직업전문학교 유성식 이사장   한차인상  대상 ', ' 개그콘서트  황해  와 만나 더욱 강력해진 웃음', '논산시  청년친화도시 조성 위한  논산형 청년정책 추진', ' 단독 선우은숙 친언니 강제추행 구속  유영재 항소심  월  일 첫 공판', '시야쥬  세계 여성의 날 기념  나의 다음 무대를 위한 준비   ', '한림대   고교생 대상 현직자 특강 프로그램  운영', ' 손보  자립준비청년 기술 교육 지원으로  돌봄  공백 해소', '신용보증기금  상반기 신입직원  명 채용', '한국수력원자력   년 상반기 신입사원 채용', '잡코리아  이공계 인재 대상  취업  특강', '조폐공사   평안감사 도과급제자 환영도  합격기원 금 은메달 신제품  ', '창원시  주력산업 현장 인력난 지원 국비  억 확보', '과천시  성평등 여성 권익 향상 위한  세계 여성의 날  행사 열어', '한패스  외국인 비자 유형별 구인 구직 서비스 오픈', '신용보증기금  상반기 신입직원  명 채용 일까지 접수', ' 에코플랜트 한수원  미래 인재 확보 나선다', '부산시   청년 사회진입 활동비 지원 사업  참여  천명 모집', '창원시  지역 및 산업 맞춤형 일자리창출 지원사업 추진', '신용보증기금   년도 상반기 신입직원  명 채용', '정읍시   취업  약자 청년들을 위한 맞춤형 지원책 마련', '건설사 줄도산에   부동산   대출 규제 과감히 완화해야 ', '한국수력원자력   년 상반기 신입사원 모집 대졸수준 신입사원  명 ', '한남대   대전형 코업 청년뉴리더 양성사업  최우수 기관 선정', '포항시  교육부 직업교육 혁신지구 선정   맞춤형 인재 양성 본격화', ' 끌어안고 만졌다 세 미성년 종업원 성추행한 사장 실형', '고양시  미디어 방송영상 콘텐츠 교육 제작 공간       개소', '김상훈  기술혁신 규제완화 해야 돈 풀어 경제 부양 안돼 ', '송파새일센터  미 취업  청년 여성 대상   백엔드 개발자 과정  ', '한수원  상반기 신입사원 채용', '고양특례시 교육발전특구 중부대학교  고양      개소', '조폐공사   평안감사 도과급제자 환영도  메달 출시', '한수원  상반기 신입사원 채용  대졸 수준  명 선발', '부산시  청년 사회진입 활동비  인당 최대  만 원 지원', ' 취업  레이스 본격화  채용 필수요건  영어 회화 능력  키울 프로그 ', '완도군  경력 단절 여성 재 취업  지원', '전문대교협  다양한 온라인 홍보 콘텐츠 운영 중', '부산외대   년 졸업생 특화 프로그램 사업 선정', '    엔터비즈니스 마스터 클래스   기 연수생 모집 엔터 산업 인 ', '   엔터비즈니스 마스터 클래스   기 연수생 모집', '부천시   문화산업 유관기관 통합사업설명회  개최', '부천시   문화산업 유관기관 통합사업설명회  개최', '한수원   년 상반기 신입사원 채용 명 선발', ' 도전하세요 정읍시   취업  취약 청년 맞춤형 지원', ' 대학생 전입하면 최대  만원 준다 제천시  전입신고 창구 개설', '한국공대   년 연속 신입생 충원율    공학 특성화로 신입생들에 ', '경북 포항시   직업교육 혁신지구  선정 이차전지 인재 양성', '  패션 소식  젝시믹스 무신사 이랜드재단', '송파새일센터  미 취업  청년 여성 대상   백엔드 개발자 과정  ', '한패스  외국인 전용 구인구직 서비스  행정 서비스 업그레이드 ', '고양시  교육발전특구 중부대       개소', ' 나는 솔로   기   억 연봉남부터 의대 대기업 출신까지 뜨거운 첫 만 ', '고용보험 가입 증가폭  대 기록   구직급여 신청   증가  고용시장 ', '울산폴리텍대학 꿈드림공작소   조선 기술교육 과정 운영', '국가산단   가동률   붕 ...

# %%
# ✅ 데이터셋 변환
def make_data(corpus):
    inputs, targets = [], []
    for sentence in corpus:
        words = sentence.split()
        for i in range(len(words) - 1):  # "I love" -> "you"
            x = [word_dict[w] for w in words[:i+1]]
            y = word_dict[words[i+1]]
            inputs.append(x)
            targets.append(y)

    return inputs, targets

inputs, targets = make_data(corpus)

# ✅ 패딩 추가 (문장 길이를 맞춤)
max_len = max(len(seq) for seq in inputs)
inputs_padded = [seq + [0] * (max_len - len(seq)) for seq in inputs]
targets = torch.tensor(targets, dtype=torch.long)

# ✅ 데이터셋 및 DataLoader 생성
class TextDataset(Dataset):
    def __init__(self, inputs, targets):
        self.inputs = torch.tensor(inputs, dtype=torch.long)
        self.targets = targets

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return self.inputs[idx], self.targets[idx]

dataset = TextDataset(inputs_padded, targets)
train_loader = DataLoader(dataset, batch_size=2, shuffle=True)

vocab_size = len(word_dict)  # 단어 개수
embed_size = 10  # 임베딩 차원
hidden_size = 16  # RNN 은닉층 크기
num_classes = len(word_dict)  # 예측할 단어 개수

# %%
# ✅ GRU 모델 정의
class GRUTextModel(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, num_classes):
        super(GRUTextModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)  # 단어 임베딩
        self.gru = nn.GRU(embed_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        x = self.embedding(x)
        out, _ = self.gru(x)
        out = self.fc(out[:, -1, :])  # 마지막 시점의 GRU 출력을 사용
        return out

# ✅ 모델 생성
model = GRUTextModel(vocab_size, embed_size, hidden_size, num_classes)

# ✅ GPU 사용 가능하면 이동
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# ✅ 손실 함수 및 최적화 함수 설정
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
num_epochs = 100
print("🚀 GRU 모델 학습 시작...")
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, (inputs, labels) in enumerate(train_loader):
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    if (epoch + 1) % 1 == 0:
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss / len(train_loader):.4f}")

# ✅ 모델 저장
model_path = "./gru_news_취업_model.pth"
torch.save(model.state_dict(), model_path)
print(f"✅ 학습된 모델이 저장되었습니다: {model_path}")
# Out:
# 🚀 GRU 모델 학습 시작...
# Epoch [1/100], Loss: 7.7541
# Epoch [2/100], Loss: 6.3901
# Epoch [3/100], Loss: 5.5648
# Epoch [4/100], Loss: 4.9519
# Epoch [5/100], Loss: 4.5075
# Epoch [6/100], Loss: 4.1643
# Epoch [7/100], Loss: 3.8682
# Epoch [8/100], Loss: 3.6813
# Epoch [9/100], Loss: 3.4951
# Epoch [10/100], Loss: 3.3519
# Epoch [11/100], Loss: 3.2314
# Epoch [12/100], Loss: 3.1272
# Epoch [13/100], Loss: 3.0204
# Epoch [14/100], Loss: 2.9848
# Epoch [15/100], Loss: 2.9185
# Epoch [16/100], Loss: 2.8396
# Epoch [17/100], Loss: 2.7973
# Epoch [18/100], Loss: 2.7400
# Epoch [19/100], Loss: 2.7239
# Epoch [20/100], Loss: 2.6626
# Epoch [21/100], Loss: 2.6167
# Epoch [22/100], Loss: 2.5701
# Epoch [23/100], Loss: 2.5675
# Epoch [24/100], Loss: 2.5432
# Epoch [25/100], Loss: 2.5016
# Epoch [26/100], Loss: 2.4890
# Epoch [27/100], Loss: 2.4321
# Epoch [28/100], Loss: 2.4373
# Epoch [29/100], Loss: 2.4183
# Epoch [30/100], Loss: 2.4000
# Epoch [31/100], Loss: 2.4260
# Epoch [32/100], Loss: 2.3954
# Epoch [33/100], Loss: 2.3564
# Epoch [34/100], Loss: 2.3454
# Epoch [35/100], Loss: 2.3552
# Epoch [36/100], Loss: 2.3361
# Epoch [37/100], Loss: 2.3408
# Epoch [38/100], Loss: 2.2871
# Epoch [39/100], Loss: 2.3005
# Epoch [40/100], Loss: 2.2785
# Epoch [41/100], Loss: 2.2836
# Epoch [42/100], Loss: 2.2761
# Epoch [43/100], Loss: 2.2557
# Epoch [44/100], Loss: 2.2092
# Epoch [45/100], Loss: 2.1952
# Epoch [46/100], Loss: 2.2450
# Epoch [47/100], Loss: 2.2152
# Epoch [48/100], Loss: 2.2062
# Epoch [49/100], Loss: 2.2510
# Epoch [50/100], Loss: 2.2200
# Epoch [51/100], Loss: 2.2030
# Epoch [52/100], Loss: 2.1718
# Epoch [53/100], Loss: 2.1908
# Epoch [54/100], Loss: 2.2164
# Epoch [55/100], Loss: 2.2273
# Epoch [56/100], Loss: 2.1565
# Epoch [57/100], Loss: 2.1997
# Epoch [58/100], Loss: 2.1466
# Epoch [59/100], Loss: 2.1351
# Epoch [60/100], Loss: 2.1547
# Epoch [61/100], Loss: 2.1534
# Epoch [62/100], Loss: 2.1713
# Epoch [63/100], Loss: 2.1327
# Epoch [64/100], Loss: 2.1140
# Epoch [65/100], Loss: 2.1460
# Epoch [66/100], Loss: 2.1300
# Epoch [67/100], Loss: 2.1106
# Epoch [68/100], Loss: 2.1151
# Epoch [69/100], Loss: 2.0810
# Epoch [70/100], Loss: 2.0794
# Epoch [71/100], Loss: 2.0620
# Epoch [72/100], Loss: 2.0747
# Epoch [73/100], Loss: 2.0660
# Epoch [74/100], Loss: 2.0523
# Epoch [75/100], Loss: 2.0624
# Epoch [76/100], Loss: 2.0713
# Epoch [77/100], Loss: 2.0290
# Epoch [78/100], Loss: 2.0572
# Epoch [79/100], Loss: 2.0706
# Epoch [80/100], Loss: 2.0382
# Epoch [81/100], Loss: 2.0116
# Epoch [82/100], Loss: 2.0374
# Epoch [83/100], Loss: 2.0039
# Epoch [84/100], Loss: 1.9791
# Epoch [85/100], Loss: 2.0481
# Epoch [86/100], Loss: 2.0482
# Epoch [87/100], Loss: 2.0107
# Epoch [88/100], Loss: 2.0096
# Epoch [89/100], Loss: 2.0241
# Epoch [90/100], Loss: 1.9808
# Epoch [91/100], Loss: 1.9850
# Epoch [92/100], Loss: 1.9775
# Epoch [93/100], Loss: 1.9639
# Epoch [94/100], Loss: 1.9726
# Epoch [95/100], Loss: 1.9745
# Epoch [96/100], Loss: 1.9685
# Epoch [97/100], Loss: 1.9676
# Epoch [98/100], Loss: 1.9901
# Epoch [99/100], Loss: 1.9520
# Epoch [100/100], Loss: 1.9445
# ✅ 학습된 모델이 저장되었습니다: ./gru_news_취업_model.pth

# %%
model_path = "./gru_news_취업_model.pth"
# ✅ 저장된 RNN 모델 불러오기
def load_model(model_path, vocab_size, embed_size, hidden_size, num_classes):
    model = GRUTextModel(vocab_size, embed_size, hidden_size, num_classes)
    model.load_state_dict(torch.load(model_path, map_location=torch.device("cpu")))
    model.eval()
    return model

# ✅ 모델 불러오기
loaded_model = load_model(model_path, vocab_size, embed_size, hidden_size, num_classes)
print("✅ 모델이 성공적으로 불러와졌습니다!")
# Out:
# ✅ 모델이 성공적으로 불러와졌습니다!

# %%
import torch.nn.functional as F

def predict_next_word(model, sentence):
    """
    저장된 RNN 모델을 사용하여 주어진 문장의 다음 단어를 예측하는 함수.
    """
    # ✅ 입력 문장을 정수 인코딩
    words = sentence.split()
    input_seq = [word_dict[w] for w in words if w in word_dict]

    # ✅ 패딩 추가 (길이를 맞추기 위해)
    input_padded = input_seq + [0] * (max_len - len(input_seq))
    input_tensor = torch.tensor([input_padded], dtype=torch.long)

    # ✅ 모델 예측
    with torch.no_grad():
        output = model(input_tensor)
        probabilities = F.softmax(output[0], dim=0)
        predicted_idx = torch.argmax(probabilities).item()
        confidence = probabilities[predicted_idx].item()

    predicted_word = idx_dict[predicted_idx]

    print(f"🔍 입력 문장: '{sentence}'")
    print(f"📊 예측된 단어: '{predicted_word}'")
    print(f"✅ 예측 확률: {confidence * 100:.2f}%")

# 🏆 샘플 문장 예측 실행
sample_sentence = "취업  "
predict_next_word(loaded_model, sample_sentence)
# Out:
# 🔍 입력 문장: '취업  '
# 📊 예측된 단어: '사이트'
# ✅ 예측 확률: 12.66%
